# %%
from numpy import *
import matplotlib.pyplot as plt
g= 9.8
m= 68.1
c= 12.5
t=2
b=0
x=[]
z=[]
y=[]
p=[]
print("forma analitica");
for i in range (50):
    v=(g*m/c)*(1-pow(math.exp(1),-(c/m)*i))
    x.append(i)
    y.append(v)
    print(i,v);
print("metodos numericos");
print(0, 0.0)
for i in range(2, 50, 2):
    v=b+(g-((c*b)/m))*(t)
    b=v
    z.append(i)
    p.append(v)
    print(i,v);
plt.plot(x,y,'r',linewidth=2,label='analitico')
plt.hold(True)
plt.plot(z,p,'k--',linewidth=2,label='metodos')
plt.legend(loc = 2)
plt.show()
# Out:
# forma analitica
# (0, 0.0)
# (1, 8.953182207901257)
# (2, 16.404980802870615)
# (3, 22.607166909502297)
# (4, 27.769291463870154)
# (5, 32.06576523242002)
# (6, 35.64175156312909)
# (7, 38.61807096510561)
# (8, 41.09528322582064)
# (9, 43.15708498693595)
# (10, 44.873137571348394)
# (11, 46.30142060418256)
# (12, 47.490190948641704)
# (13, 48.479613142547706)
# (14, 49.30311642251821)
# (15, 49.988524185047744)
# (16, 50.55899404517091)
# (17, 51.033800254117125)
# (18, 51.428984911208715)
# (19, 51.757899972254805)
# (20, 52.031658367074975)
# (21, 52.25950946789158)
# (22, 52.44915159440041)
# (23, 52.606992114011234)
# (24, 52.738363925167626)
# (25, 52.84770563798676)
# (26, 52.93871153991493)
# (27, 53.014456413232)
# (28, 53.07749942156732)
# (29, 53.129970575401444)
# (30, 53.17364269793152)
# (31, 53.20999132278378)
# (32, 53.240244547314845)
# (33, 53.26542452587653)
# (34, 53.28638200496165)
# (35, 53.30382506705669)
# (36, 53.31834305435925)
# (37, 53.33042648066185)
# (38, 53.34048360415753)
# (39, 53.34885422110625)
# (40, 53.35582114640378)
# (41, 53.361619768942425)
# (42, 53.36644600460733)
# (43, 53.37046291561302)
# (44, 53.37380621982521)
# (45, 53.37658887620956)
# (46, 53.378904901333776)
# (47, 53.38083254587018)
# (48, 53.38243693842183)
# (49, 53.38377228599821)
# metodos numericos
# (0, 0.0)
# (2, 19.6)
# (4, 32.00469897209985)
# (6, 39.855543695998584)
# (8, 44.824286832562976)
# (10, 47.968968612091984)
# (12, 49.95921508342386)
# (14, 51.21882775470732)
# (16, 52.01602755107027)
# (18, 52.52056956609587)
# (20, 52.83989057707389)
# (22, 53.04198654731108)
# (24, 53.169891632732856)
# (26, 53.25084184098071)
# (28, 53.30207464531966)
# (30, 53.33449951855033)
# (32, 53.355020987511296)
# (34, 53.36800887755854)
# (36, 53.37622881971767)
# (38, 53.38143116196522)
# (40, 53.38472368694127)
# (42, 53.38680750230792)
# (44, 53.38812633405978)
# (46, 53.38896101318615)
# (48, 53.38948927559946)
