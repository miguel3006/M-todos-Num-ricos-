# %%
from numpy import *
import math
import matplotlib.pyplot as plt

fc=0
x1=0.5
x2=2
xr=0
i=0
fx=0
ft=0
fh=math.log(x1)-0.7
fk=math.log(x2)-0.7
ft=fh*fk
fu=0
if ft>0:  
    print("forma biseccion");
    print("              iteracion"+"                         x1"+"                          x2"+"                           xr");
    while True:
        xr=(x1+x2)/2
        fc=math.log(x1)-0.7
        fx=math.log(xr)-0.7
        ft=fc*fx
        if ft>0:
            print ("{0:25} | {1:25} | {2:25} | {3:25} ".format((i),x1,x2,xr));
            x1=xr
        elif ft<0:
            print ("{0:25} | {1:25} | {2:25} | {3:25} ".format((i),x1,x2,xr));
            x2=xr 
        elif ft==0:
            print ("{0:25} | {1:25} | {2:25} | {3:25} ".format((i),x1,x2,xr)); 
            break
        #print(xr);
        if i>3:
            break
        i=i+1 

        
xi=0.5
xu=2
i=0
xr=0
e1=0
n=3
print("forma metodo falsa posicion");
while True:
    fxi=math.log(xi)-0.7
    fxu=math.log(xu)-0.7
    xr=xu-(fxu*(xi-xu))/(fxi-fxu)
    if xr==e1:
        break
    e1=xr
    fxr=math.log(xr)-0.7
    
    if fxi*fxr>0:
        xu=xr
    if fxi*fxr<0:
        xi=xr 
    if fxi*fxr==0:
        break
    print(i,xr);
          
    if i>10:
        break
    i=i+1
    
    
    
    
        
        
        
        
t=0.01
b=0
i=0
x=[]
y=[]
xl=[1.4941258,1.4941258,1.4941258 ]
p=[0.1, 0, -0.1]
print("forma grafica");
for i in range (20):
    b=t**2
    v=(math.log(b)-0.7)
    x.append(i)
    y.append(v)
    print(i,v);
    t=t+1

plt.plot(x,y,'r',linewidth=2,label='analitico')
plt.hold(True)
plt.plot(xl,p,'r',linewidth=2,label='analitico')
plt.legend(loc = 2)
plt.show()
# Out:
# forma biseccion
#               iteracion                         x1                          x2                           xr
#                         0 |                       0.5 |                         2 |                      1.25
#                         1 |                      1.25 |                         2 |                     1.625
#                         2 |                     1.625 |                         2 |                    1.8125
#                         3 |                    1.8125 |                         2 |                   1.90625
#                         4 |                   1.90625 |                         2 |                  1.953125
# forma metodo falsa posicion
# 0 2.0074148964667056
# 1 2.0108334079536174
# 2 2.0124083318169883
# 3 2.0131336687694246
# 4 2.0134676750042937
# 5 2.013621468939394
# 6 2.0136922814466347
# 7 2.0137248857065626
# 8 2.0137398976106566
# 9 2.0137468094854376
# 10 2.013749991889489
# 11 2.013751457148796
# forma grafica
# 0 -9.910340371976181
# 1 -0.6800993382936638
# 2 0.6962694441419686
# 3 1.5038801575215686
# 4 2.0775824826369558
# 5 2.522871830193547
# 6 2.886849497094232
# 7 3.1946754020929973
# 8 3.4613815221605355
# 9 3.6966701432404925
# 10 3.907169186654258
# 11 4.097607901469177
# 12 4.271479272183784
# 13 4.431436585048828
# 14 4.579542720697831
# 15 4.717433291290741
# 16 4.846427054017246
# 17 4.9676028128155405
# 18 5.081854318375729
# 19 5.1899303130006755
