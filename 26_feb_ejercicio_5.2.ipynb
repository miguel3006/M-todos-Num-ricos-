# %%
import math
import scipy as sp
import matplotlib.pyplot as plt
from numpy import *
c=4.5
b=2.5
a=-0.5
cx1=0
cx2=0
fc=0
xrb=0
x1b=0
x2b=1  
i=0
fx=0
ft=0
x=[]
y=[]
k=[]
l=[1,0,-1]
fu=0
Ev=0
Ev1=0
Et=0
Ea=0
e2=0
e1=0
n=10
l=[1,0,-1]
print("metodo biseccion ");
print("      iteracion"+"                x1"+"              x2"+"                 xr"+"              Ea"+"              Et");

while True:      
    e2=e1
    xrb=(x1b+x2b)/2
    fc=x1b**3+(-5/5)*x1b**2+(6/5)*x1b-(2/5)
    fx=xrb**3+(-5/5)*xrb**2+(6/5)*xrb-(2/5)
    fu=i**3+(-5/5)*i**2+(6/5)*i-(2/5)
    ft=fc*fx
    e1=xrb
        #print("Error verdadero");
    Es=0.01
    Ev=0.41810062
    Et=(Ev/xrb)*100
        #print("Error aproximado");
    if e2==0:
        Ea=0
    else:
        Ea=((xrb-e2)/xrb)*100    
    if ft>0:
        print("+++");
        print ("{0:15} | {1:15} | {2:15} | {3:15}  | {4:15} | {5:15} ".format((i),x1b,round(x2b,4),round(xrb,4),round(Ea,4),round(Et,4)));
        x1b=xrb
    elif ft<0:
        print("---");
        print ("{0:15} | {1:15} | {2:15} | {3:15}  | {4:15} | {5:15} ".format((i),x1b,round(x2b,4),round(xrb,4),round(Ea,4),round(Et,4)));
        x2b=xrb
    elif ft==0:
        print("===");
        print ("{0:15} | {1:15} | {2:15} | {3:15}  | {4:15} | {5:15} ".format((i),x1b,round(x2b,4),round(xrb,4),round(Ea,4),round(Et,4)));
        break
        
    if i>5:
        break 
    
    x.append(i)
    y.append(fu)
    i=i+1
    
xl=[Ev,Ev,Ev]

xl1=[Ev1,Ev1,Ev1]
plt.plot(xl,l,'k',linewidth=2,label='xr raiz 1')
plt.hold(True)
plt.plot(x,y,'r',linewidth=2,label='analitico')

plt.legend(loc = 2)
plt.show()
# Out:
# metodo biseccion
#       iteracion                x1              x2                 xr              Ea              Et
# ---
#               0 |               0 |               1 |             0.5  |               0 |         83.6201
# +++
#               1 |               0 |             0.5 |            0.25  |          -100.0 |        167.2402
# +++
#               2 |            0.25 |             0.5 |           0.375  |         33.3333 |        111.4935
# ---
#               3 |           0.375 |             0.5 |          0.4375  |         14.2857 |         95.5659
# +++
#               4 |           0.375 |          0.4375 |          0.4062  |         -7.6923 |        102.9171
# ---
#               5 |         0.40625 |          0.4375 |          0.4219  |          3.7037 |         99.1053
# +++
#               6 |         0.40625 |          0.4219 |          0.4141  |         -1.8868 |        100.9752
# +++
#               7 |       0.4140625 |          0.4219 |           0.418  |          0.9346 |        100.0316
# ---
#               8 |      0.41796875 |          0.4219 |          0.4199  |          0.4651 |         99.5663
# ---
#               9 |      0.41796875 |          0.4199 |          0.4189  |         -0.2331 |         99.7984
# ---
#              10 |      0.41796875 |          0.4189 |          0.4185  |         -0.1167 |         99.9148
# ---
#              11 |      0.41796875 |          0.4185 |          0.4182  |         -0.0584 |         99.9732
