# %%
import math
t=10
g=9.8
v=40
m=68.1



xi=12
xu=16
i=0
xr=0
e1=0
n=3
while True:
    fxi=-12-21*xi+18*xi**2-2.75*xi**3
    fxu=-12-21*xu+18*xu**2-2.75*xu**3
    xr=xu-(fxu*(xi-xu))/(fxi-fxu)
    if xr==e1:
        break
    e1=xr
    fxr=-12-21*xr+18*xr**2-2.75*xr**3
    
    #print("Error ");
    Es=(0.5*math.pow(10,(2-n)))  
    #print("Error verdadero");
    Ev=-0.41468941
    Et=(Ev/xr)*100
        #print("Error aproximado");
    if e1==0:
        Ea=0
    else:
        Ea=((xr-e1)/xr)*100
    if fxi*fxr>0:
        xu=xr
    if fxi*fxr<0:
        xi=xr 
    if fxi*fxr==0:
        break
    print(i,xr);
    
    if Ea<=Es and Ea !=0: 
        break
        
    if i>1000:
        break
    i=i+1
# Out:
# 0 9.882969432314411
# 1 8.076689231930104
# 2 7.1668940674199675
# 3 6.610404148935665
# 4 6.233020660241448
# 5 5.960147632604599
# 6 5.754049527875911
# 7 5.5934154575991055
# 8 5.4652248509126435
# 9 5.361036764830616
# 10 5.275119808481427
# 11 5.203434857988506
# 12 5.143047086339641
# 13 5.091768926511404
# 14 5.047934178936044
# 15 5.0102500435038015
# 16 4.977697266210642
# 17 4.949460991418523
# 18 4.924881780271652
# 19 4.903420211357701
# 20 4.884630835634703
# 21 4.868142703297736
# 22 4.853644591158734
# 23 4.840873646833257
# 24 4.829606553408519
# 25 4.819652578576445
# 26 4.810848050234569
# 27 4.803051924267406
# 28 4.7961421974624985
# 29 4.790012980876464
# 30 4.784572094102376
# 31 4.779739073938465
# 32 4.775443515417689
# 33 4.771623681442607
# 34 4.768225331067704
# 35 4.765200726974916
# 36 4.76250779075064
# 37 4.760109380809881
# 38 4.757972672674614
# 39 4.7560686251293625
# 40 4.75437151879253
# 41 4.752858556040604
# 42 4.751509513142119
# ...
