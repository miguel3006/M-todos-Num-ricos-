# %%
import math
import scipy as sp
import matplotlib.pyplot as plt
from numpy import *

v=40
g=9.8
m=68.1
t=10
fc=0
xrb=0
fx=0
ft=0
fu=0
Ev=0
Et=0
Ea=0
e2=0
e1=0
print("metodo biseccion ");
print("      iteracion"+"                           x1"+"              x2"+"                 xr"+"              Ea"+"              Et");
x1b=0
x2b=1   
i=0
while True:
    e2=e1
    xrb=(x1b+x2b)/2
    fc=(math.exp(-x1b)-x1b)
    fx=(math.exp(-xrb)-xrb)
    fu=(-math.exp(-(i+1))-1)
    ft=fc*fx
    e1=xrb
        #print("Error verdadero");
    Ev=0.5671432904097838
    Et=(Ev/xrb)*100
        #print("Error aproximado");
    if e2==0:
        Ea=0
    else:
        Ea=((xrb-e2)/xrb)*100
            
    if ft>0:
        print ("{0:15} | {1:25} | {2:15} | {3:15}  | {4:15} | {5:15} ".format((i),x1b,round(x2b,4),round(xrb,4),round(Ea,4),round(Et,4)));
        x1b=xrb
    elif ft<0:
        print ("{0:15} | {1:25} | {2:15} | {3:15}  | {4:15} | {5:15} ".format((i),x1b,round(x2b,4),round(xrb,4),round(Ea,4),round(Et,4)));
        x2b=xrb
    elif ft==0:
        print ("{0:15} | {1:25} | {2:15} | {3:15}  | {4:15} | {5:15} ".format((i),x1b,round(x2b,4),round(xrb,4),round(Ea,4),round(Et,4)));
        break
        #print(xr);
    if i>100:
        break
    i=i+1
# Out:
# metodo biseccion
#       iteracion                           x1              x2                 xr              Ea              Et
#               0 |                         0 |               1 |             0.5  |               0 |        113.4287
#               1 |                       0.5 |               1 |            0.75  |         33.3333 |         75.6191
#               2 |                       0.5 |            0.75 |           0.625  |           -20.0 |         90.7429
#               3 |                       0.5 |           0.625 |          0.5625  |        -11.1111 |        100.8255
#               4 |                    0.5625 |           0.625 |          0.5938  |          5.2632 |         95.5189
#               5 |                    0.5625 |          0.5938 |          0.5781  |         -2.7027 |         98.1005
#               6 |                    0.5625 |          0.5781 |          0.5703  |         -1.3699 |         99.4443
# ...
