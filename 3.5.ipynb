# %%
import math
z=-1
x=-0.5
n=20
e=0
e1=0
Es=0
Ev=0
Et=0
Ea=0
ev=0
e2=0
i=0
k=0
j=0
a=0
a1=0
a2=0
print("          iteracion"+"    valor e^x apx"+"   Error verdadero"+"    Error aproximado"+"    Error tolerado");
while True:
    e2=e1
    if i==0:
        e=e+1  
        
    else:
        
        print("{0:20} | {1:20} |".format(a,e));
        #3.5 el a
        if i%2==0:
           
            k=pow(x,i)/math.factorial(i)
            e=e2+k
            
            
        else:
            
            j=pow(x,i)/math.factorial(i)
            e=e2-j
            
        #3.5 el b
        a=1/(e+pow(x,i) /math.factorial(i))
        
    e1=e
    
    #print("Error ");
    Es=(0.5*pow(10,2-n))  
#print("Error verdadero");
    Ev=math.exp(x)
    Et=(Ev/e)*100
#print("Error aproximado");
    if e2==0:
        Ea=0
    else:
        Ea=((e-e2)/e)*100
    #print ("{0:20} | {1:20} | {2:20} | {3:20}| {4:20}".format(i,e,Et,Ea,Es));
    if Ea<=Es and Ea !=0: 
        break
    if i>200: 
        break
    i=i+1
# Out:
#           iteracion    valor e^x apx   Error verdadero    Error aproximado    Error tolerado
#                    0 |                    1 |
#                  1.0 |                  1.5 |
#   0.5714285714285714 |                1.625 |
#   0.6153846153846154 |   1.6458333333333333 |
#   0.6056782334384858 |            1.6484375 |
#   0.6066350710900474 |   1.6486979166666667 |
#   0.6065232842814647 |   1.6487196180555554 |
#   0.6065312676872047 |   1.6487211681547618 |
#   0.6065306261557636 |   1.6487212650359622 |
#   0.6065306617963636 |    1.648721270418251 |
#   0.6065306596183269 |   1.6487212706873655 |
#   0.6065306597173286 |    1.648721270699598 |
#   0.6065306597124536 |   1.6487212707001075 |
#    0.606530659712641 |    1.648721270700127 |
#   0.6065306597126333 |   1.6487212707001278 |
#   0.6065306597126335 |   1.6487212707001278 |
#   0.6065306597126335 |   1.6487212707001278 |
#   0.6065306597126335 |   1.6487212707001278 |
# ...
